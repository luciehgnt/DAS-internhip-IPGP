# %%
# %matplotlib widget
import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
fibre =  pd.read_excel('/net/runic/moby/data/projets/monidas/biagioli/Geolocation_DAS/2022/DAS_channels_2022_UTM.xlsx')
latitude = fibre['Lat'].values
longitude = fibre['Lon'].values
orientation = fibre['orientation'].values

# %%
fibre.offset.loc[200]
# Out:
# 512

# %%
plt.figure()
plt.scatter(longitude, latitude)
plt.axis('equal')
for i in range(2000, 2769):
    plt.text(longitude[i], latitude [i], fibre.channel.loc[i])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
type(20)
type(30)
# Out:
# int

# %%
min(latitude), max(latitude), min(longitude), max(longitude)
# Out:
# (4293680.35958918, 4294531.66863544, 519108.62188503, 520007.66457338)

# %%
channels = np.vstack((latitude, longitude))
channels
# Out:
# array([[4294531.66863544, 4294531.30141545, 4294530.7250024 , ...,
#         4294318.09032978, 4294318.97768409, 4294319.86503841],
#        [ 520007.66457338,  520005.80998632,  520003.99051451, ...,
#          519227.42551739,  519229.07814385,  519230.7307703 ]])
